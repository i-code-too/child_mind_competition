# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.shape
# Out:
# (3960, 82)

# %%
df_test.shape
# Out:
# (20, 59)

# %%
df_train.head()
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
#    Physical-Weight  ...  PCIAT-PCIAT_18  PCIAT-PCIAT_19  PCIAT-PCIAT_20  \
# 0             50.8  ...             4.0             2.0             4.0
# 1             46.0  ...             0.0             0.0             0.0
# 2             75.6  ...             2.0             1.0             1.0
# 3             81.6  ...             3.0             4.0             1.0
# 4              NaN  ...             NaN             NaN             NaN
#
#    PCIAT-PCIAT_Total SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0               55.0        NaN                NaN              NaN
# 1                0.0       Fall               46.0             64.0
# 2               28.0       Fall               38.0             54.0
# 3               44.0     Summer               31.0             45.0
# 4                NaN        NaN                NaN              NaN
#
#    PreInt_EduHx-Season PreInt_EduHx-computerinternet_hoursday  sii
# 0                 Fall                                    3.0  2.0
# 1               Summer                                    0.0  0.0
# 2               Summer                                    2.0  0.0
# 3               Winter                                    0.0  1.0
# 4                  NaN                                    NaN  NaN
#
# [5 rows x 82 columns]

# %%
df_test.head()
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
#    Physical-Weight  ...  BIA-BIA_TBW  PAQ_A-Season  PAQ_A-PAQ_A_Total  \
# 0             50.8  ...      32.6909           NaN                NaN
# 1             46.0  ...      27.0552           NaN                NaN
# 2             75.6  ...          NaN           NaN                NaN
# 3             81.6  ...      45.9966           NaN                NaN
# 4              NaN  ...          NaN        Summer               1.04
#
#    PAQ_C-Season PAQ_C-PAQ_C_Total  SDS-Season  SDS-SDS_Total_Raw  \
# 0           NaN               NaN         NaN                NaN
# 1          Fall             2.340        Fall               46.0
# 2        Summer             2.170        Fall               38.0
# 3        Winter             2.451      Summer               31.0
# 4           NaN               NaN         NaN                NaN
#
#    SDS-SDS_Total_T PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday
# 0              NaN                Fall                                     3.0
# 1             64.0              Summer                                     0.0
# 2             54.0              Summer                                     2.0
# 3             45.0              Winter                                     0.0
# 4              NaN                 NaN                                     NaN
#
# [5 rows x 59 columns]

# %%
print("Columns in Train Set: ", df_train.columns)
print("Columns in Test Set: ", df_test.columns)
# Out:
# Columns in Train Set:  Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
#        'PAQ_C-PAQ_C_Total', 'PCIAT-Season', 'PCIAT-PCIAT_01', 'PCIAT-PCIAT_02',
#        'PCIAT-PCIAT_03', 'PCIAT-PCIAT_04', 'PCIAT-PCIAT_05', 'PCIAT-PCIAT_06',
#        'PCIAT-PCIAT_07', 'PCIAT-PCIAT_08', 'PCIAT-PCIAT_09', 'PCIAT-PCIAT_10',
#        'PCIAT-PCIAT_11', 'PCIAT-PCIAT_12', 'PCIAT-PCIAT_13', 'PCIAT-PCIAT_14',
#        'PCIAT-PCIAT_15', 'PCIAT-PCIAT_16', 'PCIAT-PCIAT_17', 'PCIAT-PCIAT_18',
#        'PCIAT-PCIAT_19', 'PCIAT-PCIAT_20', 'PCIAT-PCIAT_Total', 'SDS-Season',
#        'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
#        'PreInt_EduHx-computerinternet_hoursday', 'sii'],
#       dtype='object')
# Columns in Test Set:  Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
#        'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
#        'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
#        'PreInt_EduHx-computerinternet_hoursday'],
#       dtype='object')

# %% [markdown]
# PCIAT features should not be used for modeling since SII is derived from PCIAT, which means including them will lead to data leakage.

# %% [markdown]
# # Data Cleaning

# %%
columns_to_keep = [col for col in df_train.columns if col in df_test.columns or col == 'sii']

df_train = df_train[columns_to_keep]

print("Updated Columns in Train Set: ", df_train.columns)
print("Columns in Test Set: ", df_test.columns)
# Out:
# Updated Columns in Train Set:  Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
#        'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
#        'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
#        'PreInt_EduHx-computerinternet_hoursday', 'sii'],
#       dtype='object')
# Columns in Test Set:  Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
#        'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
#        'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
#        'PreInt_EduHx-computerinternet_hoursday'],
#       dtype='object')

# %%
for col, dtype in df_train.dtypes.items():
    print(f"Column '{col}' has data type: {dtype}") # categorical int shown as int or float data types
# Out:
# Column 'id' has data type: object
# Column 'Basic_Demos-Enroll_Season' has data type: object
# Column 'Basic_Demos-Age' has data type: int64
# Column 'Basic_Demos-Sex' has data type: int64
# Column 'CGAS-Season' has data type: object
# Column 'CGAS-CGAS_Score' has data type: float64
# Column 'Physical-Season' has data type: object
# Column 'Physical-BMI' has data type: float64
# Column 'Physical-Height' has data type: float64
# Column 'Physical-Weight' has data type: float64
# Column 'Physical-Waist_Circumference' has data type: float64
# Column 'Physical-Diastolic_BP' has data type: float64
# Column 'Physical-HeartRate' has data type: float64
# Column 'Physical-Systolic_BP' has data type: float64
# Column 'Fitness_Endurance-Season' has data type: object
# Column 'Fitness_Endurance-Max_Stage' has data type: float64
# Column 'Fitness_Endurance-Time_Mins' has data type: float64
# Column 'Fitness_Endurance-Time_Sec' has data type: float64
# Column 'FGC-Season' has data type: object
# Column 'FGC-FGC_CU' has data type: float64
# Column 'FGC-FGC_CU_Zone' has data type: float64
# Column 'FGC-FGC_GSND' has data type: float64
# Column 'FGC-FGC_GSND_Zone' has data type: float64
# Column 'FGC-FGC_GSD' has data type: float64
# Column 'FGC-FGC_GSD_Zone' has data type: float64
# Column 'FGC-FGC_PU' has data type: float64
# Column 'FGC-FGC_PU_Zone' has data type: float64
# Column 'FGC-FGC_SRL' has data type: float64
# Column 'FGC-FGC_SRL_Zone' has data type: float64
# Column 'FGC-FGC_SRR' has data type: float64
# Column 'FGC-FGC_SRR_Zone' has data type: float64
# Column 'FGC-FGC_TL' has data type: float64
# Column 'FGC-FGC_TL_Zone' has data type: float64
# Column 'BIA-Season' has data type: object
# Column 'BIA-BIA_Activity_Level_num' has data type: float64
# Column 'BIA-BIA_BMC' has data type: float64
# Column 'BIA-BIA_BMI' has data type: float64
# Column 'BIA-BIA_BMR' has data type: float64
# Column 'BIA-BIA_DEE' has data type: float64
# Column 'BIA-BIA_ECW' has data type: float64
# Column 'BIA-BIA_FFM' has data type: float64
# Column 'BIA-BIA_FFMI' has data type: float64
# Column 'BIA-BIA_FMI' has data type: float64
# Column 'BIA-BIA_Fat' has data type: float64
# Column 'BIA-BIA_Frame_num' has data type: float64
# Column 'BIA-BIA_ICW' has data type: float64
# Column 'BIA-BIA_LDM' has data type: float64
# Column 'BIA-BIA_LST' has data type: float64
# Column 'BIA-BIA_SMM' has data type: float64
# Column 'BIA-BIA_TBW' has data type: float64
# Column 'PAQ_A-Season' has data type: object
# Column 'PAQ_A-PAQ_A_Total' has data type: float64
# Column 'PAQ_C-Season' has data type: object
# Column 'PAQ_C-PAQ_C_Total' has data type: float64
# Column 'SDS-Season' has data type: object
# Column 'SDS-SDS_Total_Raw' has data type: float64
# Column 'SDS-SDS_Total_T' has data type: float64
# Column 'PreInt_EduHx-Season' has data type: object
# Column 'PreInt_EduHx-computerinternet_hoursday' has data type: float64
# Column 'sii' has data type: float64

# %%
df_train['Basic_Demos-Sex'] = df_train['Basic_Demos-Sex'].replace({0: 'Male', 1: 'Female'})
df_train['FGC-FGC_CU_Zone'] = df_train['FGC-FGC_CU_Zone'].replace({0: 'Needs Improvement', 1: 'Healthy Fitness Zone'})
df_train['FGC-FGC_GSND_Zone'] = df_train['FGC-FGC_GSND_Zone'].replace({1: 'Weak', 2: 'Normal', 3: 'Strong'})
df_train['FGC-FGC_GSD_Zone'] = df_train['FGC-FGC_GSD_Zone'].replace({1: 'Weak', 2: 'Normal', 3: 'Strong'})
df_train['FGC-FGC_PU_Zone'] = df_train['FGC-FGC_PU_Zone'].replace({0: 'Needs Improvement', 1: 'Healthy Fitness Zone'})
df_train['FGC-FGC_SRL_Zone'] = df_train['FGC-FGC_SRL_Zone'].replace({0: 'Needs Improvement', 1: 'Healthy Fitness Zone'})
df_train['FGC-FGC_SRR_Zone'] = df_train['FGC-FGC_SRR_Zone'].replace({0: 'Needs Improvement', 1: 'Healthy Fitness Zone'})
df_train['FGC-FGC_TL_Zone'] = df_train['FGC-FGC_TL_Zone'].replace({0: 'Needs Improvement', 1: 'Healthy Fitness Zone'})
df_train['BIA-BIA_Activity_Level_num'] = df_train['BIA-BIA_Activity_Level_num'].replace({1: 'Very Light', 2: 'Light', 3: 'Moderate', 4: 'Heavy', 5: 'Exceptional'})
df_train['BIA-BIA_Frame_num'] = df_train['BIA-BIA_Frame_num'].replace({1: 'Small', 2: 'Medium', 3: 'Large'})
# df_train['PCIAT-PCIAT_01'] = df_train['PCIAT-PCIAT_01'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_02'] = df_train['PCIAT-PCIAT_02'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_03'] = df_train['PCIAT-PCIAT_03'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_04'] = df_train['PCIAT-PCIAT_04'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_05'] = df_train['PCIAT-PCIAT_05'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_06'] = df_train['PCIAT-PCIAT_06'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_07'] = df_train['PCIAT-PCIAT_07'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_08'] = df_train['PCIAT-PCIAT_08'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_09'] = df_train['PCIAT-PCIAT_09'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_10'] = df_train['PCIAT-PCIAT_10'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_11'] = df_train['PCIAT-PCIAT_11'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_12'] = df_train['PCIAT-PCIAT_12'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_13'] = df_train['PCIAT-PCIAT_13'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_14'] = df_train['PCIAT-PCIAT_14'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_15'] = df_train['PCIAT-PCIAT_15'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_16'] = df_train['PCIAT-PCIAT_16'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_17'] = df_train['PCIAT-PCIAT_17'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_18'] = df_train['PCIAT-PCIAT_18'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_19'] = df_train['PCIAT-PCIAT_19'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
# df_train['PCIAT-PCIAT_20'] = df_train['PCIAT-PCIAT_20'].replace({0: 'Does Not Apply', 1: 'Rarely', 2: 'Occasionally', 3: 'Frequently', 4: 'Often', 5: 'Always'})
df_train['PreInt_EduHx-computerinternet_hoursday'] = df_train['PreInt_EduHx-computerinternet_hoursday'].replace({0: 'Less than 1h/day', 1: 'Around 1h/day', 2: 'Around 2hs/day', 3: 'More than 3hs/day'})
df_train['sii'] = df_train['sii'].replace({0: 'Not Addicted', 1: 'Mildly Addicted', 2: 'Moderately Addicted', 3: 'Severely Addicted'})

# %%
print("Total number of inf values:\n",df_train.select_dtypes(include=[np.number]).apply(lambda x: np.isinf(x).sum()))
# Out:
# Total number of inf values:
#  Basic_Demos-Age                 0
# CGAS-CGAS_Score                 0
# Physical-BMI                    0
# Physical-Height                 0
# Physical-Weight                 0
# Physical-Waist_Circumference    0
# Physical-Diastolic_BP           0
# Physical-HeartRate              0
# Physical-Systolic_BP            0
# Fitness_Endurance-Max_Stage     0
# Fitness_Endurance-Time_Mins     0
# Fitness_Endurance-Time_Sec      0
# FGC-FGC_CU                      0
# FGC-FGC_GSND                    0
# FGC-FGC_GSD                     0
# FGC-FGC_PU                      0
# FGC-FGC_SRL                     0
# FGC-FGC_SRR                     0
# FGC-FGC_TL                      0
# BIA-BIA_BMC                     0
# BIA-BIA_BMI                     0
# BIA-BIA_BMR                     0
# BIA-BIA_DEE                     0
# BIA-BIA_ECW                     0
# BIA-BIA_FFM                     0
# BIA-BIA_FFMI                    0
# BIA-BIA_FMI                     0
# BIA-BIA_Fat                     0
# BIA-BIA_ICW                     0
# BIA-BIA_LDM                     0
# BIA-BIA_LST                     0
# BIA-BIA_SMM                     0
# BIA-BIA_TBW                     0
# PAQ_A-PAQ_A_Total               0
# PAQ_C-PAQ_C_Total               0
# SDS-SDS_Total_Raw               0
# SDS-SDS_Total_T                 0
# dtype: int64

# %%
print("Total number of NaN values: ", df_train.isna().sum())
# Out:
# Total number of NaN values:  id                                           0
# Basic_Demos-Enroll_Season                    0
# Basic_Demos-Age                              0
# Basic_Demos-Sex                              0
# CGAS-Season                               1405
# CGAS-CGAS_Score                           1539
# Physical-Season                            650
# Physical-BMI                               938
# Physical-Height                            933
# Physical-Weight                            884
# Physical-Waist_Circumference              3062
# Physical-Diastolic_BP                     1006
# Physical-HeartRate                         993
# Physical-Systolic_BP                      1006
# Fitness_Endurance-Season                  2652
# Fitness_Endurance-Max_Stage               3217
# Fitness_Endurance-Time_Mins               3220
# Fitness_Endurance-Time_Sec                3220
# FGC-Season                                 614
# FGC-FGC_CU                                1638
# FGC-FGC_CU_Zone                           1678
# FGC-FGC_GSND                              2886
# FGC-FGC_GSND_Zone                         2898
# FGC-FGC_GSD                               2886
# FGC-FGC_GSD_Zone                          2897
# FGC-FGC_PU                                1650
# FGC-FGC_PU_Zone                           1689
# FGC-FGC_SRL                               1655
# FGC-FGC_SRL_Zone                          1693
# FGC-FGC_SRR                               1653
# FGC-FGC_SRR_Zone                          1691
# FGC-FGC_TL                                1636
# FGC-FGC_TL_Zone                           1675
# BIA-Season                                1815
# BIA-BIA_Activity_Level_num                1969
# BIA-BIA_BMC                               1969
# BIA-BIA_BMI                               1969
# BIA-BIA_BMR                               1969
# BIA-BIA_DEE                               1969
# BIA-BIA_ECW                               1969
# BIA-BIA_FFM                               1969
# BIA-BIA_FFMI                              1969
# BIA-BIA_FMI                               1969
# BIA-BIA_Fat                               1969
# BIA-BIA_Frame_num                         1969
# BIA-BIA_ICW                               1969
# BIA-BIA_LDM                               1969
# BIA-BIA_LST                               1969
# BIA-BIA_SMM                               1969
# BIA-BIA_TBW                               1969
# PAQ_A-Season                              3485
# PAQ_A-PAQ_A_Total                         3485
# PAQ_C-Season                              2239
# PAQ_C-PAQ_C_Total                         2239
# SDS-Season                                1342
# SDS-SDS_Total_Raw                         1351
# SDS-SDS_Total_T                           1354
# PreInt_EduHx-Season                        420
# PreInt_EduHx-computerinternet_hoursday     659
# sii                                       1224
# dtype: int64

# %%
df_train_labelled = df_train[df_train['sii'].notna()]
df_train_labelled.shape
# Out:
# (2736, 60)

# %%
df_train_unlabelled = df_train[df_train['sii'].isna()]
df_train_unlabelled.shape
# Out:
# (1224, 60)

# %%
nan_percentage = (df_train_labelled.isna().sum()/len(df_train_labelled))*100
print("Percentage of NaN values in each column:\n", nan_percentage)
# Out:
# Percentage of NaN values in each column:
#  id                                         0.000000
# Basic_Demos-Enroll_Season                  0.000000
# Basic_Demos-Age                            0.000000
# Basic_Demos-Sex                            0.000000
# CGAS-Season                               14.400585
# CGAS-CGAS_Score                           14.400585
# Physical-Season                            5.153509
# Physical-BMI                               7.638889
# Physical-Height                            7.529240
# Physical-Weight                            5.994152
# Physical-Waist_Circumference              82.346491
# Physical-Diastolic_BP                      9.429825
# Physical-HeartRate                         9.137427
# Physical-Systolic_BP                       9.429825
# Fitness_Endurance-Season                  53.947368
# Fitness_Endurance-Max_Stage               73.282164
# Fitness_Endurance-Time_Mins               73.391813
# Fitness_Endurance-Time_Sec                73.391813
# FGC-Season                                 3.252924
# FGC-FGC_CU                                29.861111
# FGC-FGC_CU_Zone                           31.140351
# FGC-FGC_GSND                              68.128655
# FGC-FGC_GSND_Zone                         68.421053
# FGC-FGC_GSD                               68.165205
# FGC-FGC_GSD_Zone                          68.421053
# FGC-FGC_PU                                30.226608
# FGC-FGC_PU_Zone                           31.469298
# FGC-FGC_SRL                               30.153509
# FGC-FGC_SRL_Zone                          31.396199
# FGC-FGC_SRR                               30.080409
# FGC-FGC_SRR_Zone                          31.323099
# FGC-FGC_TL                                29.861111
# FGC-FGC_TL_Zone                           31.103801
# BIA-Season                                32.602339
# BIA-BIA_Activity_Level_num                33.735380
# BIA-BIA_BMC                               33.735380
# BIA-BIA_BMI                               33.735380
# BIA-BIA_BMR                               33.735380
# BIA-BIA_DEE                               33.735380
# BIA-BIA_ECW                               33.735380
# BIA-BIA_FFM                               33.735380
# BIA-BIA_FFMI                              33.735380
# BIA-BIA_FMI                               33.735380
# BIA-BIA_Fat                               33.735380
# BIA-BIA_Frame_num                         33.735380
# BIA-BIA_ICW                               33.735380
# BIA-BIA_LDM                               33.735380
# BIA-BIA_LST                               33.735380
# BIA-BIA_SMM                               33.735380
# BIA-BIA_TBW                               33.735380
# PAQ_A-Season                              86.732456
# PAQ_A-PAQ_A_Total                         86.732456
# PAQ_C-Season                              47.368421
# PAQ_C-PAQ_C_Total                         47.368421
# SDS-Season                                 7.638889
# SDS-SDS_Total_Raw                          7.638889
# SDS-SDS_Total_T                            7.711988
# PreInt_EduHx-Season                        0.621345
# PreInt_EduHx-computerinternet_hoursday     2.997076
# sii                                        0.000000
# dtype: float64

# %%
df_train_labelled = df_train_labelled.loc[:, nan_percentage <= 80]

# %%
df_train_labelled.shape
# Out:
# (2736, 57)

# %%
y = df_train_labelled[['sii']]
X = df_train_labelled.drop(columns=['sii'])

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

knn_imputer = KNNImputer(n_neighbors=5)
label_encoder = LabelEncoder()

def impute_data(df):
    for column in df.columns:
        if pd.api.types.is_numeric_dtype(df[column]):
            # Apply KNN imputation for numeric columns
            df[column] = knn_imputer.fit_transform(df[[column]])
        else:
            # Apply mode imputation for categorical columns
            mode_value = df[column].mode()[0]
            df[column].fillna(mode_value, inplace=True)
    return df

X_train = impute_data(X)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2614837233.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)

# %%
nan_percentage = (X_train.isna().sum()/len(X_train))*100
nan_percentage
# Out:
# id                                        0.0
# Basic_Demos-Enroll_Season                 0.0
# Basic_Demos-Age                           0.0
# Basic_Demos-Sex                           0.0
# CGAS-Season                               0.0
# CGAS-CGAS_Score                           0.0
# Physical-Season                           0.0
# Physical-BMI                              0.0
# Physical-Height                           0.0
# Physical-Weight                           0.0
# Physical-Diastolic_BP                     0.0
# Physical-HeartRate                        0.0
# Physical-Systolic_BP                      0.0
# Fitness_Endurance-Season                  0.0
# Fitness_Endurance-Max_Stage               0.0
# Fitness_Endurance-Time_Mins               0.0
# Fitness_Endurance-Time_Sec                0.0
# FGC-Season                                0.0
# FGC-FGC_CU                                0.0
# FGC-FGC_CU_Zone                           0.0
# FGC-FGC_GSND                              0.0
# FGC-FGC_GSND_Zone                         0.0
# FGC-FGC_GSD                               0.0
# FGC-FGC_GSD_Zone                          0.0
# FGC-FGC_PU                                0.0
# FGC-FGC_PU_Zone                           0.0
# FGC-FGC_SRL                               0.0
# FGC-FGC_SRL_Zone                          0.0
# FGC-FGC_SRR                               0.0
# FGC-FGC_SRR_Zone                          0.0
# FGC-FGC_TL                                0.0
# FGC-FGC_TL_Zone                           0.0
# BIA-Season                                0.0
# BIA-BIA_Activity_Level_num                0.0
# BIA-BIA_BMC                               0.0
# BIA-BIA_BMI                               0.0
# BIA-BIA_BMR                               0.0
# BIA-BIA_DEE                               0.0
# BIA-BIA_ECW                               0.0
# BIA-BIA_FFM                               0.0
# BIA-BIA_FFMI                              0.0
# BIA-BIA_FMI                               0.0
# BIA-BIA_Fat                               0.0
# BIA-BIA_Frame_num                         0.0
# BIA-BIA_ICW                               0.0
# BIA-BIA_LDM                               0.0
# BIA-BIA_LST                               0.0
# BIA-BIA_SMM                               0.0
# BIA-BIA_TBW                               0.0
# PAQ_C-Season                              0.0
# PAQ_C-PAQ_C_Total                         0.0
# SDS-Season                                0.0
# SDS-SDS_Total_Raw                         0.0
# SDS-SDS_Total_T                           0.0
# PreInt_EduHx-Season                       0.0
# PreInt_EduHx-computerinternet_hoursday    0.0
# dtype: float64

# %%
X_train = X_train.drop(columns=['id'])

# %%
categorical_columns = X_train.select_dtypes(include=['object', 'category']).columns
categorical_columns = [col for col in categorical_columns if col != 'id']
print(categorical_columns)
# Out:
# ['Basic_Demos-Enroll_Season', 'Basic_Demos-Sex', 'CGAS-Season', 'Physical-Season', 'Fitness_Endurance-Season', 'FGC-Season', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL_Zone', 'BIA-Season', 'BIA-BIA_Activity_Level_num', 'BIA-BIA_Frame_num', 'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season', 'PreInt_EduHx-computerinternet_hoursday']

# %%
ordinal_columns = ['FGC-FGC_CU_Zone', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL_Zone', 'BIA-BIA_Activity_Level_num', 'BIA-BIA_Frame_num', 'PreInt_EduHx-computerinternet_hoursday']
onehot_columns = [col for col in categorical_columns if col not in ordinal_columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
X_train[ordinal_columns] = ordinal_encoder.fit_transform(X_train[ordinal_columns])

# %%
for col, dtype in X_train.dtypes.items():
    print(f"Column '{col}' has data type: {dtype}")
# Out:
# Column 'Basic_Demos-Enroll_Season' has data type: object
# Column 'Basic_Demos-Age' has data type: float64
# Column 'Basic_Demos-Sex' has data type: object
# Column 'CGAS-Season' has data type: object
# Column 'CGAS-CGAS_Score' has data type: float64
# Column 'Physical-Season' has data type: object
# Column 'Physical-BMI' has data type: float64
# Column 'Physical-Height' has data type: float64
# Column 'Physical-Weight' has data type: float64
# Column 'Physical-Diastolic_BP' has data type: float64
# Column 'Physical-HeartRate' has data type: float64
# Column 'Physical-Systolic_BP' has data type: float64
# Column 'Fitness_Endurance-Season' has data type: object
# Column 'Fitness_Endurance-Max_Stage' has data type: float64
# Column 'Fitness_Endurance-Time_Mins' has data type: float64
# Column 'Fitness_Endurance-Time_Sec' has data type: float64
# Column 'FGC-Season' has data type: object
# Column 'FGC-FGC_CU' has data type: float64
# Column 'FGC-FGC_CU_Zone' has data type: float64
# Column 'FGC-FGC_GSND' has data type: float64
# Column 'FGC-FGC_GSND_Zone' has data type: float64
# Column 'FGC-FGC_GSD' has data type: float64
# Column 'FGC-FGC_GSD_Zone' has data type: float64
# Column 'FGC-FGC_PU' has data type: float64
# Column 'FGC-FGC_PU_Zone' has data type: float64
# Column 'FGC-FGC_SRL' has data type: float64
# Column 'FGC-FGC_SRL_Zone' has data type: float64
# Column 'FGC-FGC_SRR' has data type: float64
# Column 'FGC-FGC_SRR_Zone' has data type: float64
# Column 'FGC-FGC_TL' has data type: float64
# Column 'FGC-FGC_TL_Zone' has data type: float64
# Column 'BIA-Season' has data type: object
# Column 'BIA-BIA_Activity_Level_num' has data type: float64
# Column 'BIA-BIA_BMC' has data type: float64
# Column 'BIA-BIA_BMI' has data type: float64
# Column 'BIA-BIA_BMR' has data type: float64
# Column 'BIA-BIA_DEE' has data type: float64
# Column 'BIA-BIA_ECW' has data type: float64
# Column 'BIA-BIA_FFM' has data type: float64
# Column 'BIA-BIA_FFMI' has data type: float64
# Column 'BIA-BIA_FMI' has data type: float64
# Column 'BIA-BIA_Fat' has data type: float64
# Column 'BIA-BIA_Frame_num' has data type: float64
# Column 'BIA-BIA_ICW' has data type: float64
# Column 'BIA-BIA_LDM' has data type: float64
# Column 'BIA-BIA_LST' has data type: float64
# Column 'BIA-BIA_SMM' has data type: float64
# Column 'BIA-BIA_TBW' has data type: float64
# Column 'PAQ_C-Season' has data type: object
# Column 'PAQ_C-PAQ_C_Total' has data type: float64
# Column 'SDS-Season' has data type: object
# Column 'SDS-SDS_Total_Raw' has data type: float64
# Column 'SDS-SDS_Total_T' has data type: float64
# Column 'PreInt_EduHx-Season' has data type: object
# Column 'PreInt_EduHx-computerinternet_hoursday' has data type: float64

# %%
print(X_train.shape)
print(y.shape)
# Out:
# (2736, 55)
# (2736, 1)

# %%
X_train.head()
# Out:
#   Basic_Demos-Enroll_Season  Basic_Demos-Age Basic_Demos-Sex CGAS-Season  \
# 0                      Fall              5.0            Male      Winter
# 1                    Summer              9.0            Male      Spring
# 2                    Summer             10.0          Female        Fall
# 3                    Winter              9.0            Male        Fall
# 5                    Spring             13.0          Female      Winter
#
#    CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0        51.000000            Fall     16.877316             46.0
# 1        65.159266            Fall     14.035590             48.0
# 2        71.000000            Fall     16.648696             56.5
# 3        71.000000          Summer     18.292347             56.0
# 5        50.000000          Summer     22.279952             59.5
#
#    Physical-Weight  Physical-Diastolic_BP  ...  BIA-BIA_LST  BIA-BIA_SMM  \
# 0             50.8              69.755044  ...     38.91770    19.541300
# 1             46.0              75.000000  ...     39.44970    15.410700
# 2             75.6              65.000000  ...     67.02313    34.372294
# 3             81.6              60.000000  ...     58.93380    26.479800
# 5            112.2              60.000000  ...     79.69820    35.380400
#
#   BIA-BIA_TBW  PAQ_C-Season  PAQ_C-PAQ_C_Total  SDS-Season SDS-SDS_Total_Raw  \
# 0     32.6909        Spring           2.590608      Spring         40.977839
# 1     27.0552          Fall           2.340000        Fall         46.000000
# 2     53.9165        Summer           2.170000        Fall         38.000000
# 3     45.9966        Winter           2.451000      Summer         31.000000
# 5     63.1265        Spring           4.110000      Summer         40.000000
#
#    SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 0        57.647525                 Fall
# 1        64.000000               Summer
# 2        54.000000               Summer
# 3        45.000000               Winter
# 5        56.000000               Spring
#
#    PreInt_EduHx-computerinternet_hoursday
# 0                                     3.0
# 1                                     2.0
# 2                                     1.0
# 3                                     2.0
# 5                                     2.0
#
# [5 rows x 55 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)
X_train_onehot = encoder.fit_transform(X_train[onehot_columns])
onehot_df = pd.DataFrame(X_train_onehot, columns=encoder.get_feature_names_out(onehot_columns), index=X_train.index)
X_train = pd.concat([X_train.drop(columns=onehot_columns), onehot_df], axis=1)

print(X_train.shape)
# Out:
# (2736, 83)

# %%
for col, dtype in X_train.dtypes.items():
    print(f"Column '{col}' has data type: {dtype}")
# Out:
# Column 'Basic_Demos-Age' has data type: float64
# Column 'CGAS-CGAS_Score' has data type: float64
# Column 'Physical-BMI' has data type: float64
# Column 'Physical-Height' has data type: float64
# Column 'Physical-Weight' has data type: float64
# Column 'Physical-Diastolic_BP' has data type: float64
# Column 'Physical-HeartRate' has data type: float64
# Column 'Physical-Systolic_BP' has data type: float64
# Column 'Fitness_Endurance-Max_Stage' has data type: float64
# Column 'Fitness_Endurance-Time_Mins' has data type: float64
# Column 'Fitness_Endurance-Time_Sec' has data type: float64
# Column 'FGC-FGC_CU' has data type: float64
# Column 'FGC-FGC_CU_Zone' has data type: float64
# Column 'FGC-FGC_GSND' has data type: float64
# Column 'FGC-FGC_GSND_Zone' has data type: float64
# Column 'FGC-FGC_GSD' has data type: float64
# Column 'FGC-FGC_GSD_Zone' has data type: float64
# Column 'FGC-FGC_PU' has data type: float64
# Column 'FGC-FGC_PU_Zone' has data type: float64
# Column 'FGC-FGC_SRL' has data type: float64
# Column 'FGC-FGC_SRL_Zone' has data type: float64
# Column 'FGC-FGC_SRR' has data type: float64
# Column 'FGC-FGC_SRR_Zone' has data type: float64
# Column 'FGC-FGC_TL' has data type: float64
# Column 'FGC-FGC_TL_Zone' has data type: float64
# Column 'BIA-BIA_Activity_Level_num' has data type: float64
# Column 'BIA-BIA_BMC' has data type: float64
# Column 'BIA-BIA_BMI' has data type: float64
# Column 'BIA-BIA_BMR' has data type: float64
# Column 'BIA-BIA_DEE' has data type: float64
# Column 'BIA-BIA_ECW' has data type: float64
# Column 'BIA-BIA_FFM' has data type: float64
# Column 'BIA-BIA_FFMI' has data type: float64
# Column 'BIA-BIA_FMI' has data type: float64
# Column 'BIA-BIA_Fat' has data type: float64
# Column 'BIA-BIA_Frame_num' has data type: float64
# Column 'BIA-BIA_ICW' has data type: float64
# Column 'BIA-BIA_LDM' has data type: float64
# Column 'BIA-BIA_LST' has data type: float64
# Column 'BIA-BIA_SMM' has data type: float64
# Column 'BIA-BIA_TBW' has data type: float64
# Column 'PAQ_C-PAQ_C_Total' has data type: float64
# Column 'SDS-SDS_Total_Raw' has data type: float64
# Column 'SDS-SDS_Total_T' has data type: float64
# Column 'PreInt_EduHx-computerinternet_hoursday' has data type: float64
# Column 'Basic_Demos-Enroll_Season_Fall' has data type: float64
# Column 'Basic_Demos-Enroll_Season_Spring' has data type: float64
# Column 'Basic_Demos-Enroll_Season_Summer' has data type: float64
# Column 'Basic_Demos-Enroll_Season_Winter' has data type: float64
# Column 'Basic_Demos-Sex_Female' has data type: float64
# Column 'Basic_Demos-Sex_Male' has data type: float64
# Column 'CGAS-Season_Fall' has data type: float64
# Column 'CGAS-Season_Spring' has data type: float64
# Column 'CGAS-Season_Summer' has data type: float64
# Column 'CGAS-Season_Winter' has data type: float64
# Column 'Physical-Season_Fall' has data type: float64
# Column 'Physical-Season_Spring' has data type: float64
# Column 'Physical-Season_Summer' has data type: float64
# Column 'Physical-Season_Winter' has data type: float64
# Column 'Fitness_Endurance-Season_Fall' has data type: float64
# Column 'Fitness_Endurance-Season_Spring' has data type: float64
# Column 'Fitness_Endurance-Season_Summer' has data type: float64
# Column 'Fitness_Endurance-Season_Winter' has data type: float64
# Column 'FGC-Season_Fall' has data type: float64
# Column 'FGC-Season_Spring' has data type: float64
# Column 'FGC-Season_Summer' has data type: float64
# Column 'FGC-Season_Winter' has data type: float64
# Column 'BIA-Season_Fall' has data type: float64
# Column 'BIA-Season_Spring' has data type: float64
# Column 'BIA-Season_Summer' has data type: float64
# Column 'BIA-Season_Winter' has data type: float64
# Column 'PAQ_C-Season_Fall' has data type: float64
# Column 'PAQ_C-Season_Spring' has data type: float64
# Column 'PAQ_C-Season_Summer' has data type: float64
# Column 'PAQ_C-Season_Winter' has data type: float64
# Column 'SDS-Season_Fall' has data type: float64
# Column 'SDS-Season_Spring' has data type: float64
# Column 'SDS-Season_Summer' has data type: float64
# Column 'SDS-Season_Winter' has data type: float64
# Column 'PreInt_EduHx-Season_Fall' has data type: float64
# Column 'PreInt_EduHx-Season_Spring' has data type: float64
# Column 'PreInt_EduHx-Season_Summer' has data type: float64
# Column 'PreInt_EduHx-Season_Winter' has data type: float64

# %% [markdown]
# # Next Steps:
#    1) Correlation
#    2) Feature Importance
#    3) Do encoding on test dataset

# %%
X_train.describe()
# Out:
#        Basic_Demos-Age  CGAS-CGAS_Score  Physical-BMI  Physical-Height  \
# count      2736.000000      2736.000000   2736.000000      2736.000000
# mean         10.238670        65.159266     19.125667        55.897051
# std           3.427982        10.927241      4.718000         7.110994
# min           5.000000        25.000000      0.000000        36.000000
# 25%           8.000000        60.000000     15.916620        50.500000
# 50%          10.000000        65.159266     18.274247        55.897051
# 75%          12.000000        71.000000     20.829292        61.000000
# max          22.000000        95.000000     46.102914        78.500000
#
#        Physical-Weight  Physical-Diastolic_BP  Physical-HeartRate  \
# count      2736.000000            2736.000000         2736.000000
# mean         87.839592              69.755044           81.823411
# std          42.033187              13.123660           13.125404
# min           0.000000              11.000000           27.000000
# 25%          58.200000              62.000000           73.000000
# 50%          79.200000              69.000000           81.823411
# 75%         108.600000              75.000000           90.000000
# max         315.000000             179.000000          138.000000
#
#        Physical-Systolic_BP  Fitness_Endurance-Max_Stage  \
# count           2736.000000                  2736.000000
# mean             117.127926                     5.001368
# std               16.389305                     1.041901
# min               49.000000                     0.000000
# 25%              107.000000                     5.001368
# 50%              116.000000                     5.001368
# 75%              124.000000                     5.001368
# max              203.000000                    28.000000
#
#        Fitness_Endurance-Time_Mins  ...  PAQ_C-Season_Summer  \
# count                  2736.000000  ...          2736.000000
# mean                      7.394231  ...             0.125000
# std                       1.639755  ...             0.330779
# min                       0.000000  ...             0.000000
# 25%                       7.394231  ...             0.000000
# 50%                       7.394231  ...             0.000000
# 75%                       7.394231  ...             0.000000
# max                      20.000000  ...             1.000000
#
#        PAQ_C-Season_Winter  SDS-Season_Fall  SDS-Season_Spring  \
# count          2736.000000      2736.000000        2736.000000
# mean              0.140716         0.221126           0.329313
# std               0.347792         0.415081           0.470050
# min               0.000000         0.000000           0.000000
# 25%               0.000000         0.000000           0.000000
# 50%               0.000000         0.000000           0.000000
# 75%               0.000000         0.000000           1.000000
# max               1.000000         1.000000           1.000000
#
#        SDS-Season_Summer  SDS-Season_Winter  PreInt_EduHx-Season_Fall  \
# count        2736.000000        2736.000000               2736.000000
# mean            0.219664           0.229898                  0.250000
# std             0.414095           0.420844                  0.433092
# min             0.000000           0.000000                  0.000000
# 25%             0.000000           0.000000                  0.000000
# 50%             0.000000           0.000000                  0.000000
# 75%             0.000000           0.000000                  0.250000
# max             1.000000           1.000000                  1.000000
#
#        PreInt_EduHx-Season_Spring  PreInt_EduHx-Season_Summer  \
# count                 2736.000000                 2736.000000
# mean                     0.272295                    0.238304
# std                      0.445222                    0.426124
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      1.000000                    0.000000
# max                      1.000000                    1.000000
#
#        PreInt_EduHx-Season_Winter
# count                 2736.000000
# mean                     0.239401
# std                      0.426796
# min                      0.000000
# 25%                      0.000000
# 50%                      0.000000
# 75%                      0.000000
# max                      1.000000
#
# [8 rows x 83 columns]

# %%
y.describe()
# Out:
#                  sii
# count           2736
# unique             4
# top     Not Addicted
# freq            1594

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
# Ordinal Encoding for y
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[['Not Addicted', 'Mildly Addicted', 'Moderately Addicted', 'Severely Addicted']])
y_encoded = encoder.fit_transform(y[['sii']])
y_encoded = pd.DataFrame(y_encoded, columns=['sii'])
y = y_encoded

y.head()
# Out:
#    sii
# 0  2.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  1.0

# %%
for col, dtype in y.dtypes.items():
    print(f"Column '{col}' has data type: {dtype}")
# Out:
# Column 'sii' has data type: float64

# %% [markdown]
# # Feature Transformation - Standardization

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()
standard_scaler.fit_transform(X_train)

X_train.describe()
# Out:
#        Basic_Demos-Age  CGAS-CGAS_Score  Physical-BMI  Physical-Height  \
# count      2736.000000      2736.000000   2736.000000      2736.000000
# mean         10.238670        65.159266     19.125667        55.897051
# std           3.427982        10.927241      4.718000         7.110994
# min           5.000000        25.000000      0.000000        36.000000
# 25%           8.000000        60.000000     15.916620        50.500000
# 50%          10.000000        65.159266     18.274247        55.897051
# 75%          12.000000        71.000000     20.829292        61.000000
# max          22.000000        95.000000     46.102914        78.500000
#
#        Physical-Weight  Physical-Diastolic_BP  Physical-HeartRate  \
# count      2736.000000            2736.000000         2736.000000
# mean         87.839592              69.755044           81.823411
# std          42.033187              13.123660           13.125404
# min           0.000000              11.000000           27.000000
# 25%          58.200000              62.000000           73.000000
# 50%          79.200000              69.000000           81.823411
# 75%         108.600000              75.000000           90.000000
# max         315.000000             179.000000          138.000000
#
#        Physical-Systolic_BP  Fitness_Endurance-Max_Stage  \
# count           2736.000000                  2736.000000
# mean             117.127926                     5.001368
# std               16.389305                     1.041901
# min               49.000000                     0.000000
# 25%              107.000000                     5.001368
# 50%              116.000000                     5.001368
# 75%              124.000000                     5.001368
# max              203.000000                    28.000000
#
#        Fitness_Endurance-Time_Mins  ...  PAQ_C-Season_Summer  \
# count                  2736.000000  ...          2736.000000
# mean                      7.394231  ...             0.125000
# std                       1.639755  ...             0.330779
# min                       0.000000  ...             0.000000
# 25%                       7.394231  ...             0.000000
# 50%                       7.394231  ...             0.000000
# 75%                       7.394231  ...             0.000000
# max                      20.000000  ...             1.000000
#
#        PAQ_C-Season_Winter  SDS-Season_Fall  SDS-Season_Spring  \
# count          2736.000000      2736.000000        2736.000000
# mean              0.140716         0.221126           0.329313
# std               0.347792         0.415081           0.470050
# min               0.000000         0.000000           0.000000
# 25%               0.000000         0.000000           0.000000
# 50%               0.000000         0.000000           0.000000
# 75%               0.000000         0.000000           1.000000
# max               1.000000         1.000000           1.000000
#
#        SDS-Season_Summer  SDS-Season_Winter  PreInt_EduHx-Season_Fall  \
# count        2736.000000        2736.000000               2736.000000
# mean            0.219664           0.229898                  0.250000
# std             0.414095           0.420844                  0.433092
# min             0.000000           0.000000                  0.000000
# 25%             0.000000           0.000000                  0.000000
# 50%             0.000000           0.000000                  0.000000
# 75%             0.000000           0.000000                  0.250000
# max             1.000000           1.000000                  1.000000
#
#        PreInt_EduHx-Season_Spring  PreInt_EduHx-Season_Summer  \
# count                 2736.000000                 2736.000000
# mean                     0.272295                    0.238304
# std                      0.445222                    0.426124
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      1.000000                    0.000000
# max                      1.000000                    1.000000
#
#        PreInt_EduHx-Season_Winter
# count                 2736.000000
# mean                     0.239401
# std                      0.426796
# min                      0.000000
# 25%                      0.000000
# 50%                      0.000000
# 75%                      0.000000
# max                      1.000000
#
# [8 rows x 83 columns]

# %% [markdown]
# # Feature Transformation - Normalization

# %%
# from sklearn.preprocessing import MinMaxScaler

# minmax_scaler = MinMaxScaler(feature_range=(-1, 1))
# minmax_scaler.fit_transform(X_train)

# X_train.describe()

# %% [markdown]
# # Correlation

# %%
print(X_train.columns)
# Out:
# Index(['Basic_Demos-Age', 'CGAS-CGAS_Score', 'Physical-BMI', 'Physical-Height',
#        'Physical-Weight', 'Physical-Diastolic_BP', 'Physical-HeartRate',
#        'Physical-Systolic_BP', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND', 'FGC-FGC_GSND_Zone',
#        'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU', 'FGC-FGC_PU_Zone',
#        'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR', 'FGC-FGC_SRR_Zone',
#        'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-BIA_Activity_Level_num',
#        'BIA-BIA_BMC', 'BIA-BIA_BMI', 'BIA-BIA_BMR', 'BIA-BIA_DEE',
#        'BIA-BIA_ECW', 'BIA-BIA_FFM', 'BIA-BIA_FFMI', 'BIA-BIA_FMI',
#        'BIA-BIA_Fat', 'BIA-BIA_Frame_num', 'BIA-BIA_ICW', 'BIA-BIA_LDM',
#        'BIA-BIA_LST', 'BIA-BIA_SMM', 'BIA-BIA_TBW', 'PAQ_C-PAQ_C_Total',
#        'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T',
#        'PreInt_EduHx-computerinternet_hoursday',
#        'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Spring',
#        'Basic_Demos-Enroll_Season_Summer', 'Basic_Demos-Enroll_Season_Winter',
#        'Basic_Demos-Sex_Female', 'Basic_Demos-Sex_Male', 'CGAS-Season_Fall',
#        'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter',
#        'Physical-Season_Fall', 'Physical-Season_Spring',
#        'Physical-Season_Summer', 'Physical-Season_Winter',
#        'Fitness_Endurance-Season_Fall', 'Fitness_Endurance-Season_Spring',
#        'Fitness_Endurance-Season_Summer', 'Fitness_Endurance-Season_Winter',
#        'FGC-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer',
#        'FGC-Season_Winter', 'BIA-Season_Fall', 'BIA-Season_Spring',
#        'BIA-Season_Summer', 'BIA-Season_Winter', 'PAQ_C-Season_Fall',
#        'PAQ_C-Season_Spring', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Winter',
#        'SDS-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Summer',
#        'SDS-Season_Winter', 'PreInt_EduHx-Season_Fall',
#        'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Summer',
#        'PreInt_EduHx-Season_Winter'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = X_train.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix of Numerical Features in X_train")
plt.show()

# %%
threshold = 0.9

high_corr_pairs = correlation_matrix.abs().unstack().sort_values(ascending=False)
high_corr_pairs = high_corr_pairs[high_corr_pairs < 1] # removing self correlations
high_corr_pairs = high_corr_pairs[high_corr_pairs > threshold]

print("Highly correlated feature pairs (correlation > 0.9):\n")
print(high_corr_pairs)
# Out:
# Highly correlated feature pairs (correlation > 0.9):
#
# Basic_Demos-Sex_Female            Basic_Demos-Sex_Male                1.000000
# Basic_Demos-Sex_Male              Basic_Demos-Sex_Female              1.000000
# BIA-BIA_FFM                       BIA-BIA_BMR                         1.000000
# BIA-BIA_BMR                       BIA-BIA_FFM                         1.000000
# BIA-BIA_TBW                       BIA-BIA_BMR                         0.999652
#                                                                         ...
# Basic_Demos-Enroll_Season_Summer  PreInt_EduHx-Season_Summer          0.931468
# PreInt_EduHx-Season_Spring        Basic_Demos-Enroll_Season_Spring    0.919438
# Basic_Demos-Enroll_Season_Spring  PreInt_EduHx-Season_Spring          0.919438
# FGC-FGC_SRL                       FGC-FGC_SRR                         0.914535
# FGC-FGC_SRR                       FGC-FGC_SRL                         0.914535
# Length: 124, dtype: float64

# %%
features_to_drop = set()
for feature1, feature2 in high_corr_pairs.index:
    if feature1 not in features_to_drop and feature2 not in features_to_drop:
        # Drop one feature (arbitrarily choose feature2)
        features_to_drop.add(feature2)

print(f"Number of columns to drop: {len(features_to_drop)}")
print(f"Columns to drop: {features_to_drop}")
# Out:
# Number of columns to drop: 17
# Columns to drop: {'Basic_Demos-Sex_Male', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Spring', 'BIA-BIA_Fat', 'BIA-BIA_BMR', 'SDS-SDS_Total_T', 'BIA-BIA_DEE', 'BIA-BIA_BMC', 'Basic_Demos-Enroll_Season_Summer', 'BIA-BIA_FFM', 'BIA-BIA_TBW', 'FGC-FGC_SRR', 'BIA-BIA_SMM', 'BIA-BIA_ECW', 'BIA-BIA_ICW', 'PreInt_EduHx-Season_Winter', 'BIA-BIA_LDM'}

# %%
X_train = X_train.drop(columns=list(features_to_drop))
X_train.shape
# Out:
# (2736, 66)

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
y_squeezed = y.squeeze()

# %%
from sklearn.feature_selection import chi2, f_classif
from scipy.stats import pearsonr
import pandas as pd

# Function to calculate feature importance
def calculate_feature_importance(X_train, y):
    feature_scores = []
    
    # Make sure y is a 1D array-like structure (like a Series)
    y = y.values if isinstance(y, pd.DataFrame) else y  # In case y is a DataFrame, convert to array
    
    for column in X_train.columns:
        if X_train[column].dtype == 'object':  # X column is categorical
            if y.dtype == 'object':  # Both X and y are categorical
                chi2_score, _ = chi2(X_train[[column]], y)
                feature_scores.append((column, chi2_score[0], 'Chi-Square'))
            else:  # X is categorical, y is numerical
                f_stat, _ = f_classif(X_train[[column]], y)
                feature_scores.append((column, f_stat[0], 'F-Statistic'))
        else:  # X column is numerical
            if y.dtype != 'object':  # Both X and y are numerical
                corr, _ = pearsonr(X_train[column], y)
                feature_scores.append((column, abs(corr), 'Pearson R'))
            else:  # X is numerical, y is categorical
                f_stat, _ = f_classif(X_train[[column]], y)
                feature_scores.append((column, f_stat[0], 'F-Statistic'))
    
    # Create a DataFrame for results
    importance_df = pd.DataFrame(feature_scores, columns=['Feature', 'Score', 'Method'])
    return importance_df.sort_values(by='Score', ascending=False)

# Calculate feature importance
importance_df = calculate_feature_importance(X_train, y_squeezed)

# %%
print('Importance of features: \n', importance_df)
# Out:
# Importance of features:
#                         Feature     Score     Method
# 0              Basic_Demos-Age  0.365990  Pearson R
# 3              Physical-Height  0.360489  Pearson R
# 4              Physical-Weight  0.316554  Pearson R
# 31           SDS-SDS_Total_Raw  0.219720  Pearson R
# 2                 Physical-BMI  0.213332  Pearson R
# ..                         ...       ...        ...
# 65  PreInt_EduHx-Season_Summer  0.004926  Pearson R
# 30           PAQ_C-PAQ_C_Total  0.004124  Pearson R
# 35            CGAS-Season_Fall  0.003912  Pearson R
# 10  Fitness_Endurance-Time_Sec  0.003877  Pearson R
# 12             FGC-FGC_CU_Zone  0.001482  Pearson R
#
# [66 rows x 3 columns]

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\sudha\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy in c:\users\sudha\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\sudha\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split data into training and validation sets (if needed)
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y, test_size=0.2, random_state=42)

# Initialize the XGBoost model
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# Fit the model on training data
xgb_model.fit(X_train_split, y_train_split)

# Make predictions
y_pred = xgb_model.predict(X_val_split)

# Evaluate the model performance
accuracy = accuracy_score(y_val_split, y_pred)
print(f"Accuracy on validation data: {accuracy:.4f}")

# Get feature importance
feature_importances = xgb_model.feature_importances_

# Create a DataFrame of feature importance
importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Display the feature importances
print("Feature Importance:")
print(importance_df)
# Out:
# c:\Users\sudha\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:20:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy on validation data: 0.5712
# Feature Importance:
#                                    Feature  Importance
# 0                          Basic_Demos-Age    0.040182
# 45         Fitness_Endurance-Season_Summer    0.025828
# 51                         BIA-Season_Fall    0.025068
# 46         Fitness_Endurance-Season_Winter    0.023453
# 32  PreInt_EduHx-computerinternet_hoursday    0.023119
# ..                                     ...         ...
# 39                    Physical-Season_Fall    0.009757
# 50                       FGC-Season_Winter    0.009431
# 12                         FGC-FGC_CU_Zone    0.009165
# 20                        FGC-FGC_SRL_Zone    0.006774
# 54                       BIA-Season_Winter    0.005858
#
# [66 rows x 2 columns]

# %%
len(df_train.columns)
# Out:
# 60

# %%
nan_percentage = (df_train.isna().sum()/len(df_train))*100
print("Percentage of NaN values in each column:\n", nan_percentage)

df_train = df_train.loc[:, nan_percentage <= 80]
# Out:
# Percentage of NaN values in each column:
#  id                                         0.000000
# Basic_Demos-Enroll_Season                  0.000000
# Basic_Demos-Age                            0.000000
# Basic_Demos-Sex                            0.000000
# CGAS-Season                               35.479798
# CGAS-CGAS_Score                           38.863636
# Physical-Season                           16.414141
# Physical-BMI                              23.686869
# Physical-Height                           23.560606
# Physical-Weight                           22.323232
# Physical-Waist_Circumference              77.323232
# Physical-Diastolic_BP                     25.404040
# Physical-HeartRate                        25.075758
# Physical-Systolic_BP                      25.404040
# Fitness_Endurance-Season                  66.969697
# Fitness_Endurance-Max_Stage               81.237374
# Fitness_Endurance-Time_Mins               81.313131
# Fitness_Endurance-Time_Sec                81.313131
# FGC-Season                                15.505051
# FGC-FGC_CU                                41.363636
# FGC-FGC_CU_Zone                           42.373737
# FGC-FGC_GSND                              72.878788
# FGC-FGC_GSND_Zone                         73.181818
# FGC-FGC_GSD                               72.878788
# FGC-FGC_GSD_Zone                          73.156566
# FGC-FGC_PU                                41.666667
# FGC-FGC_PU_Zone                           42.651515
# FGC-FGC_SRL                               41.792929
# FGC-FGC_SRL_Zone                          42.752525
# FGC-FGC_SRR                               41.742424
# FGC-FGC_SRR_Zone                          42.702020
# FGC-FGC_TL                                41.313131
# FGC-FGC_TL_Zone                           42.297980
# BIA-Season                                45.833333
# BIA-BIA_Activity_Level_num                49.722222
# BIA-BIA_BMC                               49.722222
# BIA-BIA_BMI                               49.722222
# BIA-BIA_BMR                               49.722222
# BIA-BIA_DEE                               49.722222
# BIA-BIA_ECW                               49.722222
# BIA-BIA_FFM                               49.722222
# BIA-BIA_FFMI                              49.722222
# BIA-BIA_FMI                               49.722222
# BIA-BIA_Fat                               49.722222
# BIA-BIA_Frame_num                         49.722222
# BIA-BIA_ICW                               49.722222
# BIA-BIA_LDM                               49.722222
# BIA-BIA_LST                               49.722222
# BIA-BIA_SMM                               49.722222
# BIA-BIA_TBW                               49.722222
# PAQ_A-Season                              88.005051
# PAQ_A-PAQ_A_Total                         88.005051
# PAQ_C-Season                              56.540404
# PAQ_C-PAQ_C_Total                         56.540404
# SDS-Season                                33.888889
# SDS-SDS_Total_Raw                         34.116162
# SDS-SDS_Total_T                           34.191919
# PreInt_EduHx-Season                       10.606061
# PreInt_EduHx-computerinternet_hoursday    16.641414
# sii                                       30.909091
# dtype: float64

# %%
y = df_train[['sii']]
X = df_train.drop(columns=['sii'])

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

knn_imputer = KNNImputer(n_neighbors=5)
label_encoder = LabelEncoder()

def impute_data(df):
    for column in df.columns:
        if pd.api.types.is_numeric_dtype(df[column]):
            # Apply KNN imputation for numeric columns
            df[column] = knn_imputer.fit_transform(df[[column]])
        else:
            # Apply mode imputation for categorical columns
            mode_value = df[column].mode()[0]
            df[column].fillna(mode_value, inplace=True)
    return df

df_X_train = impute_data(X)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5412\2865927186.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)

# %%
df_X_train.shape
# Out:
# (3960, 54)

# %%
df_X_train = df_X_train.drop(columns=['id'])

# %%
categorical_columns = df_X_train.select_dtypes(include=['object', 'category']).columns
print(categorical_columns)
# Out:
# Index(['Basic_Demos-Enroll_Season', 'Basic_Demos-Sex', 'CGAS-Season',
#        'Physical-Season', 'Fitness_Endurance-Season', 'FGC-Season',
#        'FGC-FGC_CU_Zone', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR_Zone',
#        'FGC-FGC_TL_Zone', 'BIA-Season', 'BIA-BIA_Activity_Level_num',
#        'BIA-BIA_Frame_num', 'PAQ_C-Season', 'SDS-Season',
#        'PreInt_EduHx-Season', 'PreInt_EduHx-computerinternet_hoursday'],
#       dtype='object')

# %%
ordinal_columns = ['FGC-FGC_CU_Zone', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL_Zone', 'BIA-BIA_Activity_Level_num', 'BIA-BIA_Frame_num', 'PreInt_EduHx-computerinternet_hoursday']
onehot_columns = [col for col in categorical_columns if col not in ordinal_columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
df_X_train[ordinal_columns] = ordinal_encoder.fit_transform(df_X_train[ordinal_columns])

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)
df_X_train_onehot = encoder.fit_transform(df_X_train[onehot_columns])
onehot_df = pd.DataFrame(df_X_train_onehot, columns=encoder.get_feature_names_out(onehot_columns), index=df_X_train.index)
df_X_train = pd.concat([df_X_train.drop(columns=onehot_columns), onehot_df], axis=1)

print(df_X_train.shape)
# Out:
# (3960, 81)

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()
standard_scaler.fit_transform(df_X_train)

df_X_train.describe()
# Out:
#        Basic_Demos-Age  CGAS-CGAS_Score  Physical-BMI  Physical-Height  \
# count      3960.000000      3960.000000   3960.000000      3960.000000
# mean         10.433586        65.454771     19.331929        55.946713
# std           3.574648        17.467643      4.467224         6.534029
# min           5.000000        25.000000      0.000000        33.000000
# 25%           8.000000        61.000000     16.487441        51.700000
# 50%          10.000000        65.454771     19.331929        55.946713
# 75%          13.000000        68.000000     20.041241        59.500000
# max          22.000000       999.000000     59.132048        78.500000
#
#        Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# count      3960.000000                   3960.000000            3960.000000
# mean         89.038615                     27.278508              69.648951
# std          39.279241                      2.650007              11.755368
# min           0.000000                     18.000000               0.000000
# 25%          62.400000                     27.278508              64.000000
# 50%          89.038615                     27.278508              69.648951
# 75%         101.200000                     27.278508              73.000000
# max         315.000000                     50.000000             179.000000
#
#        Physical-HeartRate  Physical-Systolic_BP  FGC-FGC_CU  ...  \
# count         3960.000000           3960.000000  3960.00000  ...
# mean            81.597236            116.983074    11.25969  ...
# std             11.827929             14.734967     9.04093  ...
# min             27.000000              0.000000     0.00000  ...
# 25%             76.000000            109.000000     7.00000  ...
# 50%             81.597236            116.983074    11.25969  ...
# 75%             87.000000            121.000000    11.25969  ...
# max            138.000000            203.000000   115.00000  ...
#
#        PAQ_C-Season_Summer  PAQ_C-Season_Winter  SDS-Season_Fall  \
# count          3960.000000          3960.000000      3960.000000
# mean              0.098737             0.118687         0.156313
# std               0.298347             0.323461         0.363198
# min               0.000000             0.000000         0.000000
# 25%               0.000000             0.000000         0.000000
# 50%               0.000000             0.000000         0.000000
# 75%               0.000000             0.000000         0.000000
# max               1.000000             1.000000         1.000000
#
#        SDS-Season_Spring  SDS-Season_Summer  SDS-Season_Winter  \
# count        3960.000000        3960.000000        3960.000000
# mean            0.518687           0.160354           0.164646
# std             0.499714           0.366980           0.370908
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             1.000000           0.000000           0.000000
# 75%             1.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        PreInt_EduHx-Season_Fall  PreInt_EduHx-Season_Spring  \
# count               3960.000000                 3960.000000
# mean                   0.209091                    0.354798
# std                    0.406711                    0.478512
# min                    0.000000                    0.000000
# 25%                    0.000000                    0.000000
# 50%                    0.000000                    0.000000
# 75%                    0.000000                    1.000000
# max                    1.000000                    1.000000
#
#        PreInt_EduHx-Season_Summer  PreInt_EduHx-Season_Winter
# count                 3960.000000                 3960.000000
# mean                     0.207323                    0.228788
# std                      0.405440                    0.420105
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      1.000000                    1.000000
#
# [8 rows x 81 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df_X_train.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix of Numerical Features in df_X_train")
plt.show()

# %%
threshold = 0.9

high_corr_pairs = correlation_matrix.abs().unstack().sort_values(ascending=False)
high_corr_pairs = high_corr_pairs[high_corr_pairs < 1] # removing self correlations
high_corr_pairs = high_corr_pairs[high_corr_pairs > threshold]

print("Highly correlated feature pairs (correlation > 0.9):\n")
print(high_corr_pairs)
# Out:
# Highly correlated feature pairs (correlation > 0.9):
#
# BIA-BIA_FFM                       BIA-BIA_BMR                         1.000000
# BIA-BIA_BMR                       BIA-BIA_FFM                         1.000000
#                                   BIA-BIA_TBW                         0.999607
# BIA-BIA_TBW                       BIA-BIA_BMR                         0.999607
#                                   BIA-BIA_FFM                         0.999607
#                                                                         ...
# PreInt_EduHx-Season_Fall          Basic_Demos-Enroll_Season_Fall      0.925293
# FGC-FGC_SRR                       FGC-FGC_SRL                         0.913432
# FGC-FGC_SRL                       FGC-FGC_SRR                         0.913432
# PreInt_EduHx-Season_Winter        Basic_Demos-Enroll_Season_Winter    0.900179
# Basic_Demos-Enroll_Season_Winter  PreInt_EduHx-Season_Winter          0.900179
# Length: 118, dtype: float64

# %%
features_to_drop = set()
for feature1, feature2 in high_corr_pairs.index:
    if feature1 not in features_to_drop and feature2 not in features_to_drop:
        # Drop one feature (arbitrarily choose feature2)
        features_to_drop.add(feature2)

print(f"Number of columns to drop: {len(features_to_drop)}")
print(f"Columns to drop: {features_to_drop}")
# Out:
# Number of columns to drop: 14
# Columns to drop: {'SDS-SDS_Total_Raw', 'BIA-BIA_Fat', 'PreInt_EduHx-Season_Fall', 'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_LST', 'BIA-BIA_FFM', 'FGC-FGC_SRL', 'BIA-BIA_TBW', 'BIA-BIA_SMM', 'BIA-BIA_ECW', 'Basic_Demos-Enroll_Season_Winter', 'BIA-BIA_ICW', 'BIA-BIA_LDM'}

# %%
df_X_train = df_X_train.drop(columns=list(features_to_drop))
df_X_train.shape
# Out:
# (3960, 67)

# %%
df_X_train.isna().sum()
# Out:
# Basic_Demos-Age               0
# CGAS-CGAS_Score               0
# Physical-BMI                  0
# Physical-Height               0
# Physical-Weight               0
#                              ..
# SDS-Season_Summer             0
# SDS-Season_Winter             0
# PreInt_EduHx-Season_Spring    0
# PreInt_EduHx-Season_Summer    0
# PreInt_EduHx-Season_Winter    0
# Length: 67, dtype: int64

# %%
y.isna().sum()
# Out:
# sii    1224
# dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.semi_supervised import LabelSpreading
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

def semi_supervised_classification(df_X_train, y, test_size=0.2, random_state=42):
    """
    Perform semi-supervised multi-class classification.
    
    Parameters:
    df_X_train (DataFrame): Numerical feature matrix with no missing values
    y (Series/array): Categorical target with missing values
    test_size (float): Proportion of data to use for testing
    random_state (int): Random seed for reproducibility
    
    Returns:
    dict: Classification results
    """
    # Ensure y is a Series
    if isinstance(y, pd.DataFrame):
        y = y.squeeze()

    # Separate the non-missing values and the missing values in y
    labeled_mask = ~y.isna()
    y_labeled = y[labeled_mask]
    
    # Ordinal Encoding for y (only for the non-missing values)
    encoder = OrdinalEncoder(categories=[['Not Addicted', 'Mildly Addicted', 'Moderately Addicted', 'Severely Addicted']])
    y_encoded = encoder.fit_transform(y_labeled.values.reshape(-1, 1))  # Encoding the labeled data only
    
    # Create a new y with the encoded values, keeping NaN for the unlabeled rows
    y_transductive = y.copy()  # Copy the original y
    y_transductive[labeled_mask] = y_encoded.flatten()  # Replace only the labeled rows with the encoded values
    y_transductive[~labeled_mask] = -1  # Mark the unlabeled rows with -1
    
    # Convert to numpy arrays
    X = df_X_train.values
    y_array = y_transductive.values
    
    # Split labeled data into train and test
    X_labeled = X[labeled_mask]  # Features where y is labeled
    y_labeled = y_array[labeled_mask]  # Labels where y is not NaN
    
    # Split the data into training and test sets (using only labeled data)
    X_train, X_test, y_train, y_test = train_test_split(
        X_labeled, y_labeled, test_size=test_size, random_state=random_state
    )
    
    # Scale features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Label Spreading for semi-supervised learning
    label_spreader = LabelSpreading(
        kernel='rbf',
        alpha=0.8,
        max_iter=30,
        n_jobs=-1
    )
    label_spreader.fit(X_scaled, y_array)  # Train on the entire dataset (labeled + unlabeled)
    
    # Get propagated labels
    propagated_labels = label_spreader.transduction_
    
    # Prepare data for Random Forest
    # Use both original labeled and propagated labels
    valid_label_mask = propagated_labels != -1
    X_for_rf = X_scaled[valid_label_mask]  # Only use rows with valid labels
    y_for_rf = propagated_labels[valid_label_mask]  # Corresponding propagated labels
    
    # Train Random Forest Classifier
    rf_classifier = RandomForestClassifier(
        n_estimators=100,
        random_state=random_state,
        class_weight='balanced'
    )
    rf_classifier.fit(X_for_rf, y_for_rf)
    
    # Prepare results
    results = {
        'propagated_labels': propagated_labels,
        'classifier': rf_classifier,
        'scaler': scaler
    }
    
    # If we have a test set, evaluate performance
    if len(X_test) > 0:
        X_test_scaled = scaler.transform(X_test)
        y_pred = rf_classifier.predict(X_test_scaled)
        
        results.update({
            'test_predictions': y_pred,
            'accuracy': accuracy_score(y_test, y_pred),
            'classification_report': classification_report(y_test, y_pred)
        })
    
    return results

# Usage example (replace with your actual data)
results = semi_supervised_classification(df_X_train, y)
print(results['classification_report'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[745], line 104
#     101     return results
#     103 # Usage example (replace with your actual data)
# --> 104 results = semi_supervised_classification(df_X_train, y)
#     105 print(results['classification_report'])
#
# Cell In[745], line 64, in semi_supervised_classification(df_X_train, y, test_size, random_state)
#      57 # Label Spreading for semi-supervised learning
#      58 label_spreader = LabelSpreading(
#      59     kernel='rbf',
#      60     alpha=0.8,
#      61     max_iter=30,
#      62     n_jobs=-1
#      63 )
# ---> 64 label_spreader.fit(X_scaled, y_array)  # Train on the entire dataset (labeled + unlabeled)
#      66 # Get propagated labels
#      67 propagated_labels = label_spreader.transduction_
#
# File c:\Users\sudha\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\sudha\anaconda3\Lib\site-packages\sklearn\semi_supervised\_label_propagation.py:265, in BaseLabelPropagation.fit(self, X, y)
#     258 X, y = self._validate_data(
#     259     X,
#     260     y,
#     261     accept_sparse=["csr", "csc"],
#     262     reset=True,
#     263 )
#     264 self.X_ = X
# --> 265 check_classification_targets(y)
#     267 # actual graph construction (implementations should override this)
#     268 graph_matrix = self._build_graph()
#
# File c:\Users\sudha\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py:221, in check_classification_targets(y)
#     213 y_type = type_of_target(y, input_name="y")
#     214 if y_type not in [
#     215     "binary",
#     216     "multiclass",
#    (...)
#     219     "multilabel-sequences",
#     220 ]:
# --> 221     raise ValueError(
#     222         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     223         "classifier, which expects discrete classes on a "
#     224         "regression target with continuous values."
#     225     )
#
# ValueError: Unknown label type: unknown. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
